# %%
import math
import random
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

df = pd.read_csv("DallasFortWorthArlington.csv")
data = "DallasFortWorthArlington.csv"
np.genfromtxt(data, delimiter = ",")
df.rename(columns={'nan':"dat"})

A = np.array(df["AttendancePercent"])
U = np.array(df["Unemployment"])

C = np.array(df["CovidTotalCountyCases"])

samples = np.zeros(1000)
samples1 = np.zeros(1000)


for m in np.arange(0,1000,1):
    sample1 = random.sample(list(C),30)
    sample2 = random.sample(list(A),30)
    samples[m] = (np.mean(sample1)-np.mean(sample2))/np.sqrt(((np.std(sample1,ddof=29))**2+(np.std(sample2,ddof=29))**2)/30)

for m in np.arange(0,1000,1):
    sample3 = random.sample(list(C),30)
    sample4 = random.sample(list(U),30)
    samples1[m] = (np.mean(sample4)-np.mean(sample3))/np.sqrt(((np.std(sample3,ddof=29))**2+(np.std(sample4,ddof=29))**2)/30)


plt.subplot()
plt.hist(samples, density = True, bins = 50)
x = np.linspace(-1000, 1000,100)
plt.xlabel("Covid_FortWorthArlington");plt.xlim(0,10)
plt.ylabel("Density_attendance")
# Out:
# Text(0, 0.5, 'Density_attendance')

# %%
plt.subplot()
plt.hist(samples1, density = True, bins = 50)
x = np.linspace(-100, 100,100)
plt.xlabel("Covid_FortWorthArlington");plt.xlim(5,10)
plt.ylabel("Density_unemployment")
# Out:
# Text(0, 0.5, 'Density_unemployment')

# %%
y = C
x1 = A
x2 = U


# Guess
m = -8
b = 1
predicted_y = m*x1 + m*x2 + b
for m in np.arange(0, 17, .05):
    predicted_y = m*x1 + m*x2 + b
    err = predicted_y - y
    SSE = np.sum( err**2 )
    plt.plot(m, SSE, 'o')
plt.xlabel("model slope")
plt.ylabel("Sum of Squared Error")
    
# Matrix
X = np.c_[np.ones(62),x1, x2]

from numpy.linalg import inv
tmp = inv(np.matmul(np.transpose(X),X))


INTERCEPT, SLOPE1, SLOPE2 = tmp @ np.transpose(X) @ y
print("Our intercept is ",INTERCEPT, "our slope1", SLOPE1, "and our slope2 is", SLOPE2)

import statsmodels.api as sm

model = sm.OLS(y,X).fit()
model.summary()
# Out:
# Our intercept is  -161997.06359080249 our slope1 4059.219708818538 and our slope2 is -0.47836917954204294
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     180.9
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):           6.73e-26
# Time:                        23:24:46   Log-Likelihood:                -626.79
# No. Observations:                  62   AIC:                             1260.
# Df Residuals:                      59   BIC:                             1266.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -1.62e+05    6.2e+04     -2.613      0.011   -2.86e+05    -3.8e+04
# x1          4059.2197    567.024      7.159      0.000    2924.607    5193.832
# x2            -0.4784      0.051     -9.370      0.000      -0.581      -0.376
# ==============================================================================
# Omnibus:                        4.525   Durbin-Watson:                   0.599
# Prob(Omnibus):                  0.104   Jarque-Bera (JB):                5.383
# Skew:                          -0.105   Prob(JB):                       0.0678
# Kurtosis:                       4.428   Cond. No.                     2.11e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.11e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df1 = pd.read_csv("DallasIrving.csv")
data1 = "DallasIrvin.csv"
np.genfromtxt(data, delimiter = ",")
df.rename(columns={'nan':"dat"})

A1 = np.array(df1["AttendancePercent"])
U1 = np.array(df1["Unemployment"])

C1 = np.array(df1["CovidTotalCountyCases"])

samples2 = np.zeros(1000)
samples3 = np.zeros(1000)


for m in np.arange(0,1000,1):
    sample5 = random.sample(list(C1),30)
    sample6 = random.sample(list(A1),30)
    samples2[m] = (np.mean(sample5)-np.mean(sample6))/np.sqrt(((np.std(sample5,ddof=29))**2+(np.std(sample6,ddof=29))**2)/30)

for m in np.arange(0,1000,1):
    sample7 = random.sample(list(C1),30)
    sample8 = random.sample(list(U1),30)
    samples3[m] = (np.mean(sample8)-np.mean(sample7))/np.sqrt(((np.std(sample7,ddof=29))**2+(np.std(sample8,ddof=29))**2)/30)


plt.subplot()
plt.hist(samples2, density = True, bins = 50)
x = np.linspace(-1000, 1000,100)
plt.xlabel("Covid_Irving");plt.xlim(5,10)
plt.ylabel("Density_attendance")
# Out:
# Text(0, 0.5, 'Density_attendance')

# %%
plt.subplot()
plt.hist(samples3, density = True, bins = 50)
x = np.linspace(-1000, 1000,100)
plt.xlabel("Covid_Irving");plt.xlim(2,6)
plt.ylabel("Density_unemployment")
# Out:
# Text(0, 0.5, 'Density_unemployment')

# %%
y = C1
x3 = A1
x4 = U1


# Guess
m = -8
b = 1
predicted_y = m*x3 + m*x4 + b
for m in np.arange(0, 17, .05):
    predicted_y = m*x3 + m*x4 + b
    err = predicted_y - y
    SSE = np.sum( err**2 )
    plt.plot(m, SSE, 'o')
plt.xlabel("model slope")
plt.ylabel("Sum of Squared Error")
    
# Matrix
X = np.c_[np.ones(54),x3, x4]

from numpy.linalg import inv
tmp = inv(np.matmul(np.transpose(X),X))


INTERCEPT, SLOPE1, SLOPE2 = tmp @ np.transpose(X) @ y
print("Our intercept is ",INTERCEPT, "our slope1", SLOPE1, "and our slope2 is", SLOPE2)

import statsmodels.api as sm

model = sm.OLS(y,X).fit()
model.summary()
# Out:
# Our intercept is  357536.57428590255 our slope1 -1395.4081961607308 and our slope2 is -0.7596282016216069
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     14.09
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):           1.35e-05
# Time:                        23:25:54   Log-Likelihood:                -583.75
# No. Observations:                  54   AIC:                             1174.
# Df Residuals:                      51   BIC:                             1179.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.575e+05   1.03e+05      3.457      0.001     1.5e+05    5.65e+05
# x1         -1395.4082   1216.451     -1.147      0.257   -3837.536    1046.719
# x2            -0.7596      0.179     -4.252      0.000      -1.118      -0.401
# ==============================================================================
# Omnibus:                        6.604   Durbin-Watson:                   0.108
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                6.670
# Skew:                           0.855   Prob(JB):                       0.0356
# Kurtosis:                       2.801   Cond. No.                     1.04e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df2 = pd.read_csv("ElPaso.csv")
data2 = "ElPaso.csv"
np.genfromtxt(data, delimiter = ",")
df.rename(columns={'nan':"dat"})

A2 = np.array(df2["AttendancePercent"])
U2 = np.array(df2["Unemployment"])

C2 = np.array(df2["CovidTotalCountyCases"])

samples4 = np.zeros(1000)
samples5 = np.zeros(1000)


for m in np.arange(0,1000,1):
    sample9 = random.sample(list(C2),30)
    sample10 = random.sample(list(A2),30)
    samples4[m] = (np.mean(sample9)-np.mean(sample10))/np.sqrt(((np.std(sample9,ddof=29))**2+(np.std(sample10,ddof=29))**2)/30)

for m in np.arange(0,1000,1):
    sample11 = random.sample(list(C2),30)
    sample12 = random.sample(list(U2),30)
    samples5[m] = (np.mean(sample11)-np.mean(sample12))/np.sqrt(((np.std(sample11,ddof=29))**2+(np.std(sample12,ddof=29))**2)/30)


plt.subplot()
plt.hist(samples4, density = True, bins = 50)
x = np.linspace(-1000, 1000,100)
plt.xlabel("Covid_ElPaso");plt.xlim(0,5)
plt.ylabel("Density_attendance")
# Out:
# Text(0, 0.5, 'Density_attendance')

# %%
plt.subplot()
plt.hist(samples5, density = True, bins = 50)
x = np.linspace(-1000, 1000,100)
plt.xlabel("Covid_ElPaso");plt.xlim(0,1)
plt.ylabel("Density_unemployment")
# Out:
# Text(0, 0.5, 'Density_unemployment')

# %%
y = C2
x5 = A2
x6 = U2


# Guess
m = -8
b = 1
predicted_y = m*x5 + m*x6 + b
for m in np.arange(0, 17, .05):
    predicted_y = m*x5 + m*x6 + b
    err = predicted_y - y
    SSE = np.sum( err**2 )
    plt.plot(m, SSE, 'o')
plt.xlabel("model slope")
plt.ylabel("Sum of Squared Error")
    
# Matrix
X = np.c_[np.ones(49),x5, x6]

from numpy.linalg import inv
tmp = inv(np.matmul(np.transpose(X),X))


INTERCEPT, SLOPE1, SLOPE2 = tmp @ np.transpose(X) @ y
print("Our intercept is ",INTERCEPT, "our slope1", SLOPE1, "and our slope2 is", SLOPE2)

import statsmodels.api as sm

model = sm.OLS(y,X).fit()
model.summary()
# Out:
# Our intercept is  220186.69269539748 our slope1 -1264.8142457992712 and our slope2 is -2.298109659796413
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     2.140
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):              0.129
# Time:                        23:26:57   Log-Likelihood:                -534.94
# No. Observations:                  49   AIC:                             1076.
# Df Residuals:                      46   BIC:                             1082.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.202e+05   1.89e+05      1.167      0.249    -1.6e+05       6e+05
# x1         -1264.8142   1999.669     -0.633      0.530   -5289.939    2760.311
# x2            -2.2981      1.234     -1.862      0.069      -4.782       0.186
# ==============================================================================
# Omnibus:                       27.960   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.466
# Skew:                           1.963   Prob(JB):                     2.21e-10
# Kurtosis:                       5.524   Cond. No.                     2.70e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df3 = pd.read_csv("Montogomery.csv")
data3 = "Montogomery.csv"
np.genfromtxt(data, delimiter = ",")
df.rename(columns={'nan':"dat"})

A3 = np.array(df3["AttendancePercent"])
U3 = np.array(df3["Unemployment"])

C3 = np.array(df3["CovidTotalCountyCases"])


samples6 = np.zeros(1000)
samples7 = np.zeros(1000)


for m in np.arange(0,1000,1):
    sample13 = random.sample(list(C3),30)
    sample14 = random.sample(list(A3),30)
    samples6[m] = (np.mean(sample13)-np.mean(sample14))/np.sqrt(((np.std(sample13,ddof=29))**2+(np.std(sample14,ddof=29))**2)/30)

for m in np.arange(0,1000,1):
    sample15 = random.sample(list(C3),30)
    sample16 = random.sample(list(U3),30)
    samples7[m] = (np.mean(sample15)-np.mean(sample16))/np.sqrt(((np.std(sample15,ddof=29))**2+(np.std(sample16,ddof=29))**2)/30)



plt.subplot()
plt.hist(samples6, density = True, bins = 50)
x = np.linspace(-100, 100,100)
plt.xlabel("Covid_Montogomery");plt.xlim(5,10)
plt.ylabel("Density_attendance")
# Out:
# Text(0, 0.5, 'Density_attendance')

# %%
plt.subplot()
plt.hist(samples7, density = True, bins = 50)
x = np.linspace(-100, 100,100)
plt.xlabel("Covid_Montogomery");plt.xlim(0,5)
plt.ylabel("Density_unemployment")
# Out:
# Text(0, 0.5, 'Density_unemployment')

# %%
y = C3
x7 = A3
x8 = U3


# Guess
m = -8
b = 1
predicted_y = m*x7 + m*x8 + b
for m in np.arange(0, 17, .05):
    predicted_y = m*x7 + m*x8 + b
    err = predicted_y - y
    SSE = np.sum( err**2 )
    plt.plot(m, SSE, 'o')
plt.xlabel("model slope")
plt.ylabel("Sum of Squared Error")
    
# Matrix
X = np.c_[np.ones(52),x7, x8]

from numpy.linalg import inv
tmp = inv(np.matmul(np.transpose(X),X))


INTERCEPT, SLOPE1, SLOPE2 = tmp @ np.transpose(X) @ y
print("Our intercept is ",INTERCEPT, "our slope1", SLOPE1, "and our slope2 is", SLOPE2)

import statsmodels.api as sm

model = sm.OLS(y,X).fit()
model.summary()
# Out:
# Our intercept is  570328.443039277 our slope1 -4124.1172287230365 and our slope2 is -2.537462044482668
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     145.5
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):           2.44e-21
# Time:                        23:27:44   Log-Likelihood:                -505.85
# No. Observations:                  52   AIC:                             1018.
# Df Residuals:                      49   BIC:                             1024.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.703e+05   8.59e+04      6.638      0.000    3.98e+05    7.43e+05
# x1         -4124.1172    932.300     -4.424      0.000   -5997.644   -2250.591
# x2            -2.5375      0.224    -11.340      0.000      -2.987      -2.088
# ==============================================================================
# Omnibus:                        0.236   Durbin-Watson:                   0.532
# Prob(Omnibus):                  0.889   Jarque-Bera (JB):                0.417
# Skew:                          -0.110   Prob(JB):                        0.812
# Kurtosis:                       2.621   Cond. No.                     5.88e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.88e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import seaborn as sns
plt.subplots()
sns.distplot(samples, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'FortWorthArlington_Attendance')
sns.distplot(samples1, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'FortWorthArlington_Unemployment')
plt.xlabel("Covid_FortWorthArlington")
plt.legend()
# Out:
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
plt.subplots()
sns.distplot(samples2, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'Irving_Attendance')
sns.distplot(samples3, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'Irvingn_Unemployment')
plt.xlabel("Covid_Irving")
plt.legend()
# Out:
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
plt.subplots()
sns.distplot(samples4, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'ElPaso_Attendance')
sns.distplot(samples5, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'ElPaso_Unemployment')
plt.xlabel("Covid_ElPaso")
plt.legend()
# Out:
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
plt.subplots()
sns.distplot(samples6, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'Montogomery_Attendance')
sns.distplot(samples7, hist= False, kde = True, kde_kws = {'linewidth' : 4}, label = 'Montogomery_Unemployment')
plt.xlabel("Covid_Montogomery")
plt.legend()
# Out:
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/loah/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
